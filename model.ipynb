# %%
#Import libraries
import pandas as pd
import seaborn as sns
import matplotlib as plt
from scipy import stats

# %%
#import relevent data
our_data = pd.read_csv('relevent_data.csv')
our_data
# Out:
#        complaint_id complaint_date resolved_date  \
# 0             42835     2019-07-01    2020-05-01
# 1             24601     2011-11-01    2012-08-01
# 2             24601     2011-11-01    2012-08-01
# 3             26146     2012-07-01    2013-09-01
# 4             40253     2018-08-01    2019-02-01
# ...             ...            ...           ...
# 28100         35671     2016-08-01    2017-02-01
# 28101         35671     2016-08-01    2017-02-01
# 28102         35671     2016-08-01    2017-02-01
# 28103         35671     2016-08-01    2017-02-01
# 28104         35671     2016-08-01    2017-02-01
#
#                                      contact_reason           fado_type  \
# 0                           Report-domestic dispute  Abuse of Authority
# 1                                  Moving violation         Discourtesy
# 2                                  Moving violation  Offensive Language
# 3      PD suspected C/V of violation/crime - street  Abuse of Authority
# 4                                    Report-dispute               Force
# ...                                             ...                 ...
# 28100                              Moving violation         Discourtesy
# 28101                              Moving violation  Abuse of Authority
# 28102                              Moving violation  Abuse of Authority
# 28103                              Moving violation  Abuse of Authority
# 28104                              Moving violation  Abuse of Authority
#
#                          allegation               outcome_description  \
# 0      Failure to provide RTKA card  No arrest made or summons issued
# 1                            Action   Moving violation summons issued
# 2                              Race   Moving violation summons issued
# 3                          Question  No arrest made or summons issued
# 4                    Physical force    Arrest - other violation/crime
# ...                             ...                               ...
# 28100                          Word   Moving violation summons issued
# 28101   Interference with recording   Moving violation summons issued
# 28102            Search (of person)   Moving violation summons issued
# 28103                Vehicle search   Moving violation summons issued
# 28104                         Frisk   Moving violation summons issued
#
#                               board_disposition  complainant_age_incident  \
# 0      Substantiated (Command Lvl Instructions)                      38.0
# 1                       Substantiated (Charges)                      26.0
# 2                       Substantiated (Charges)                      26.0
# 3                       Substantiated (Charges)                      45.0
# 4          Substantiated (Command Discipline A)                      16.0
# ...                                         ...                       ...
# 28100                           Unsubstantiated                      21.0
# 28101                           Unsubstantiated                      21.0
# 28102       Substantiated (Formalized Training)                      21.0
# 28103       Substantiated (Formalized Training)                      21.0
# 28104       Substantiated (Formalized Training)                      21.0
#
#          complainant_gender  ... first_name  last_name  \
# 0                    Female  ...   Jonathan       Ruiz
# 1                      Male  ...       John      Sears
# 2                      Male  ...       John      Sears
# 3                      Male  ...       John      Sears
# 4      No Records Available  ...      Noemi     Sierra
# ...                     ...  ...        ...        ...
# 28100                  Male  ...     Tomasz   Pulawski
# 28101                  Male  ...     Tomasz   Pulawski
# 28102                  Male  ...     Tomasz   Pulawski
# 28103                  Male  ...     Tomasz   Pulawski
# 28104                  Male  ...     Tomasz   Pulawski
#
#                  command_at_incident   command_now   rank_incident  \
# 0                       078 Precinct  078 Precinct  Police Officer
# 1      Patrol Borough Brooklyn South  078 Precinct  Police Officer
# 2      Patrol Borough Brooklyn South  078 Precinct  Police Officer
# 3      Patrol Borough Brooklyn South  078 Precinct  Police Officer
# 4                       078 Precinct  078 Precinct  Police Officer
# ...                              ...           ...             ...
# 28100                   066 Precinct  078 Precinct  Police Officer
# 28101                   066 Precinct  078 Precinct  Police Officer
# 28102                   066 Precinct  078 Precinct  Police Officer
# 28103                   066 Precinct  078 Precinct  Police Officer
# 28104                   066 Precinct  078 Precinct  Police Officer
#
#              rank_now mos_age_incident mos_gender  mos_ethnicity precinct
# 0      Police Officer               32       Male       Hispanic     78.0
# 1      Police Officer               24       Male          White     67.0
# 2      Police Officer               24       Male          White     67.0
# 3      Police Officer               25       Male          White     67.0
# 4      Police Officer               39     Female       Hispanic     67.0
# ...               ...              ...        ...            ...      ...
# 28100        Sergeant               36       Male          White     66.0
# 28101        Sergeant               36       Male          White     66.0
# 28102        Sergeant               36       Male          White     66.0
# 28103        Sergeant               36       Male          White     66.0
# 28104        Sergeant               36       Male          White     66.0
#
# [28105 rows x 22 columns]

# %%
def dataframe_correlation(dataframe):
    return dataframe.corr()

def boxplot(dataframe, column_name):
    sns.boxplot(dataframe[column_name])

def histogram(dataframe, column_name, num_bins):
    plt.hist(dataframe[column_name], num_bins)

def heatmap(dataframe):
    sns.heatmap(dataframe_correlation(dataframe))

# %%
boxplot(our_data, 'complainant_age_incident')
